# %% [markdown]
# <a href="https://colab.research.google.com/github/H3avenii/115-1/blob/main/411414842_H2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
目前金幣數量 = int(input("請輸入目前金幣數量："))
獲得金幣數量 = int(input("請輸入獲得金幣數量："))
total = 目前金幣數量 + 獲得金幣數量
print(f"任務完成！你現在有{total}枚金幣")
# Out:
# 請輸入目前金幣數量：500
# 請輸入獲得金幣數量：250
# 任務完成！你現在有750枚金幣
