# %% [markdown]
# <a href="https://colab.research.google.com/github/H3avenii/115-1/blob/main/%20411414842_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello\nhello")
# Out:
# hello
# hello

# %%
a=5
b=2.5
c="python"
print(type(c))
# Out:
# <class 'str'>

# %%
x=20
y=30
temp=x
x=y
y=temp
print(x,y)
# Out:
# 30 20

# %%
t=5
h=5
print(id(h))
# Out:
# 10446536

# %%
本金 = 50000
年利率 = 0.015
年 = 5
總 = 本金 * ((1+年利率)**年)
print(總)
# Out:
# 53864.20019421873
