# %% [markdown]
# <a href="https://colab.research.google.com/github/H3avenii/115-1/blob/main/411414842_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
本金 = 50000
年利率 = 0.015
年 = 5
總 = 本金 * ((1+年利率)**年)
print(總)
# Out:
# 53864.20019421873
